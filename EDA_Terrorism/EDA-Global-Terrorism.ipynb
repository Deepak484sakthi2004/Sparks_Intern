# %% [markdown]
# # GLOBAL TERRORISM - EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')
# Loading the dataset 
df = pd.read_csv('global_terrorism.csv', encoding='ISO-8859-1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
d=df.isnull().sum().to_dict()
d
# Out:
# {'eventid': 0,
#  'iyear': 0,
#  'imonth': 0,
#  'iday': 0,
#  'approxdate': 172452,
#  'extended': 0,
#  'resolution': 179471,
#  'country': 0,
#  'country_txt': 0,
#  'region': 0,
#  'region_txt': 0,
#  'provstate': 421,
#  'city': 434,
#  'latitude': 4556,
#  'longitude': 4557,
#  'specificity': 6,
#  'vicinity': 0,
#  'location': 126196,
#  'summary': 66129,
#  'crit1': 0,
#  'crit2': 0,
#  'crit3': 0,
#  'doubtterr': 1,
#  'alternative': 152680,
#  'alternative_txt': 152680,
#  'multiple': 1,
#  'success': 0,
#  'suicide': 0,
#  'attacktype1': 0,
#  'attacktype1_txt': 0,
#  'attacktype2': 175377,
#  'attacktype2_txt': 175377,
#  'attacktype3': 181263,
#  'attacktype3_txt': 181263,
#  'targtype1': 0,
#  'targtype1_txt': 0,
#  'targsubtype1': 10373,
#  'targsubtype1_txt': 10373,
#  'corp1': 42550,
#  'target1': 636,
#  'natlty1': 1559,
#  'natlty1_txt': 1559,
#  'targtype2': 170547,
#  'targtype2_txt': 170547,
#  'targsubtype2': 171006,
#  'targsubtype2_txt': 171006,
#  'corp2': 171574,
#  'target2': 170671,
#  'natlty2': 170863,
#  'natlty2_txt': 170863,
#  'targtype3': 180515,
#  'targtype3_txt': 180515,
#  'targsubtype3': 180594,
#  'targsubtype3_txt': 180594,
#  'corp3': 180665,
#  'target3': 180516,
#  'natlty3': 180544,
#  'natlty3_txt': 180544,
#  'gname': 0,
#  'gsubname': 175801,
#  'gname2': 179678,
#  'gsubname2': 181531,
#  'gname3': 181367,
#  'gsubname3': 181671,
#  'motive': 131130,
#  'guncertain1': 380,
#  'guncertain2': 179736,
#  'guncertain3': 181371,
#  'individual': 0,
#  'nperps': 71115,
#  'nperpcap': 69489,
#  'claimed': 66120,
#  'claimmode': 162608,
#  'claimmode_txt': 162608,
#  'claim2': 179801,
#  'claimmode2': 181075,
#  'claimmode2_txt': 181075,
#  'claim3': 181373,
#  'claimmode3': 181558,
#  'claimmode3_txt': 181558,
#  'compclaim': 176852,
#  'weaptype1': 0,
#  'weaptype1_txt': 0,
#  'weapsubtype1': 20768,
#  'weapsubtype1_txt': 20768,
#  'weaptype2': 168564,
#  'weaptype2_txt': 168564,
#  'weapsubtype2': 170149,
#  'weapsubtype2_txt': 170149,
#  'weaptype3': 179828,
#  'weaptype3_txt': 179828,
#  'weapsubtype3': 179998,
#  'weapsubtype3_txt': 179998,
#  'weaptype4': 181618,
#  'weaptype4_txt': 181618,
#  'weapsubtype4': 181621,
#  'weapsubtype4_txt': 181621,
#  'weapdetail': 67670,
#  'nkill': 10313,
#  'nkillus': 64446,
#  'nkillter': 66958,
#  'nwound': 16311,
#  'nwoundus': 64702,
#  'nwoundte': 69143,
#  'property': 0,
#  'propextent': 117626,
#  'propextent_txt': 117626,
#  'propvalue': 142702,
#  'propcomment': 123732,
#  'ishostkid': 178,
#  'nhostkid': 168119,
#  'nhostkidus': 168174,
#  'nhours': 177628,
#  'ndays': 173567,
#  'divert': 181367,
#  'kidhijcountry': 178386,
#  'ransom': 104310,
#  'ransomamt': 180341,
#  'ransomamtus': 181128,
#  'ransompaid': 180917,
#  'ransompaidus': 181139,
#  'ransomnote': 181177,
#  'hostkidoutcome': 170700,
#  'hostkidoutcome_txt': 170700,
#  'nreleased': 171291,
#  'addnotes': 153402,
#  'scite1': 66191,
#  'scite2': 104758,
#  'scite3': 138175,
#  'dbsource': 0,
#  'INT_LOG': 0,
#  'INT_IDEO': 0,
#  'INT_MISC': 0,
#  'INT_ANY': 0,
#  'related': 156653}

# %% [markdown]
# ## FEATURE ENGINEERING ON THE DATA

# %%
# Removing columns that are not useful for our analysis
df1 = df[['iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'city', 'latitude', 'longitude', 'attacktype1_txt', 'targtype1_txt', 'weaptype1_txt', 'nkill', 'nwound']]

# Check for missing values
print(df1.isnull().sum())

# Filling the missing values with 0
df1.fillna(0)

# Renaming the columns 
df1.rename(columns={'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country', 'region_txt':'Region', 'city':'City', 'latitude':'Latitude', 'longitude':'Longitude', 'attacktype1_txt':'AttackType', 'targtype1_txt':'TargetType', 'weaptype1_txt':'WeaponType', 'nkill':'Fatalities', 'nwound':'Injuries'}, inplace=True)
# Out:
# iyear                  0
# imonth                 0
# iday                   0
# country_txt            0
# region_txt             0
# city                 434
# latitude            4556
# longitude           4557
# attacktype1_txt        0
# targtype1_txt          0
# weaptype1_txt          0
# nkill              10313
# nwound             16311
# dtype: int64

# %%
# Convert string dates to DateTime format
df1['Date'] = pd.to_datetime(df1['Year'].astype(str) + '-' +
                             df1['Month'].astype(str) + '-' + 
                             df1['Day'].astype(str), errors='coerce')

df1.drop(['Day', 'Month', 'Year'], axis=1, inplace=True)

# %%
print(df1.info())
df1.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Country     181691 non-null  object
#  1   Region      181691 non-null  object
#  2   City        181257 non-null  object
#  3   Latitude    177135 non-null  float64
#  4   Longitude   177134 non-null  float64
#  5   AttackType  181691 non-null  object
#  6   TargetType  181691 non-null  object
#  7   WeaponType  181691 non-null  object
#  8   Fatalities  171378 non-null  float64
#  9   Injuries    165380 non-null  float64
#  10  Date        180800 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(6)
# memory usage: 15.2+ MB
# None
# Country           0
# Region            0
# City            434
# Latitude       4556
# Longitude      4557
# AttackType        0
# TargetType        0
# WeaponType        0
# Fatalities    10313
# Injuries      16311
# Date            891
# dtype: int64

# %%
city=df1['City'].value_counts().to_dict()
city
# Out:
# {'Unknown': 9775,
#  'Baghdad': 7589,
#  'Karachi': 2652,
#  'Lima': 2359,
#  'Mosul': 2265,
#  'Belfast': 2171,
#  'Santiago': 1621,
#  'Mogadishu': 1581,
#  'San Salvador': 1558,
#  'Istanbul': 1048,
#  'Athens': 1019,
#  'Bogota': 984,
#  'Kirkuk': 925,
#  'Beirut': 918,
#  'Medellin': 848,
#  'Benghazi': 840,
#  'Peshawar': 819,
#  'Quetta': 803,
#  'Guatemala City': 755,
#  'Baqubah': 745,
#  'Kabul': 738,
#  'Srinagar': 658,
#  'Jerusalem': 636,
#  'Paris': 612,
#  'Fallujah': 582,
#  'Tripoli': 565,
#  'Dhaka': 557,
#  'Rome': 551,
#  'Arish': 521,
#  'Ramadi': 509,
#  'Manila': 488,
#  'Aleppo': 486,
#  'Sanaa': 472,
#  'Buenos Aires': 465,
#  'New York City': 460,
#  'Ayacucho': 459,
#  'Maiduguri': 442,
#  'Imphal': 426,
#  'Tikrit': 418,
#  'Madrid': 414,
#  'Algiers': 407,
#  'London': 399,
#  'Damascus': 371,
#  'Londonderry': 366,
#  'Kandahar': 363,
#  'Gaza': 337,
#  'Bilbao': 335,
#  'Abu Ghraib': 324,
#  'Colombo': 323,
#  'Cali': 311,
#  'Ajaccio': 305,
#  'Ankara': 289,
#  'Aden': 285,
#  'Tehran': 277,
#  'Tuz Khormato': 277,
#  'Rafah': 274,
#  'Donostia-San Sebastian': 272,
#  'Samarra': 268,
#  'Jalalabad': 266,
#  'Sheikh Zuweid': 263,
#  'Madain': 259,
#  'Johannesburg': 255,
#  'Taizz': 254,
#  'Baiji': 246,
#  'Bujumbura': 242,
#  'Lahore': 233,
#  'Bastia': 226,
#  'Barcelona': 223,
#  'Muqdadiyah': 222,
#  'Tarmiyah': 220,
#  'Bangkok': 220,
#  'Grozny': 218,
#  'Cairo': 216,
#  'Basra': 214,
#  'Taji': 211,
#  'Mahmudiyah': 210,
#  'Milan': 204,
#  'Kismayo': 204,
#  'Hebron': 203,
#  'Managua': 197,
#  'Donetsk': 195,
#  'Makhachkala': 194,
#  'Santa Ana': 193,
#  'Jaffna': 191,
#  'Lashkar Gah': 190,
#  'Ghazni': 189,
#  'Sidon': 188,
#  'San Miguel': 184,
#  'Khost': 183,
#  'La Paz': 182,
#  'Sirte': 182,
#  'Huancayo': 181,
#  'Bara': 171,
#  'Tokyo': 171,
#  'Nablus': 168,
#  'Yusufiyah': 168,
#  'Batticaloa': 165,
#  'Tegucigalpa': 164,
#  'Berlin': 160,
#  'Jamrud': 160,
#  'New Delhi': 157,
#  'Zamboanga City': 157,
#  'Tel Aviv': 155,
#  'Karma': 154,
#  'Baidoa': 152,
#  'Dera Bugti': 152,
#  'Cotabato City': 152,
#  'Islamabad': 148,
#  'Derna': 148,
#  'Valparaiso': 145,
#  'Bannu': 144,
#  'Landi Kotal': 144,
#  'Hillah': 143,
#  'San Juan': 143,
#  'Soweto': 143,
#  'Chittagong': 142,
#  'Kunduz': 142,
#  'Turin': 142,
#  'Pamplona': 139,
#  'Amritsar': 138,
#  'Trincomalee': 138,
#  'Yala': 138,
#  'Mohmand district': 138,
#  'Moscow': 136,
#  'Kathmandu': 132,
#  'Caracas': 132,
#  'Durban': 132,
#  'Nazran': 131,
#  'Karbala': 131,
#  'Herat': 131,
#  'Kano': 129,
#  'Nahrawan': 129,
#  'Hangu': 129,
#  'Armagh': 125,
#  'Tal Afar': 125,
#  'Hyderabad': 125,
#  'Concepcion': 124,
#  'Beledweyne': 124,
#  'Dera Ismail Khan': 124,
#  'Diyarbakir': 124,
#  'Bajaur district': 122,
#  'Dublin': 121,
#  'Dawr district': 120,
#  'Sangin district': 117,
#  'Dushanbe': 117,
#  'Port-au-Prince': 117,
#  'Tarin Kot': 117,
#  'Balad': 117,
#  'Sui': 116,
#  'Muang': 115,
#  'Bucaramanga': 114,
#  'San Vicente': 114,
#  'Brussels': 113,
#  'Ashkelon': 112,
#  'Los Angeles': 112,
#  'Newry': 112,
#  'Rawalpindi': 111,
#  'Mexico City': 111,
#  'San Francisco': 111,
#  'Vavuniya': 110,
#  'Latifiyah': 110,
#  'Hawijah district': 110,
#  'Turbat': 108,
#  'Miran Shah': 108,
#  'Hawijah': 107,
#  'Izmir': 106,
#  'Thessaloniki': 105,
#  'Iskandariyah': 105,
#  'Husseiniyah': 104,
#  'Afgoye': 104,
#  'Shirqat': 104,
#  'Galkayo': 103,
#  'Davao City': 103,
#  'Sopore': 102,
#  'San Jose': 101,
#  'Saba al-Bor': 99,
#  'Sderot': 99,
#  'Frankfurt': 98,
#  'Quito': 98,
#  'Riyadh': 98,
#  'Vitoria': 97,
#  'Shabqadar': 96,
#  'Mukalla': 95,
#  'Cape Town': 95,
#  'Khuzdar': 95,
#  'Gereshk': 94,
#  'Cordoba': 93,
#  'Khyber district': 92,
#  'Kohat': 92,
#  'Merca': 91,
#  'Homs': 90,
#  'Barrancabermeja': 89,
#  'Bosaso': 88,
#  'Washington': 86,
#  'Qalat': 86,
#  'Cucuta': 86,
#  'Panama City': 86,
#  'Orakzai district': 86,
#  'Miami': 85,
#  'Shindand district': 85,
#  'Puli Alam': 85,
#  'Vina del Mar': 85,
#  'Ramallah': 85,
#  'Sadiyah': 85,
#  'Albu Bali': 85,
#  'Adana': 84,
#  'Nairobi': 84,
#  'Cerro de Pasco': 84,
#  'Jakarta': 84,
#  'Kurram district': 84,
#  'Nahri Saraj district': 83,
#  'Hamburg': 83,
#  'Khasavyurt': 83,
#  'Khalidiyah': 82,
#  'West Berlin': 82,
#  'Zinjibar': 82,
#  'Chaman': 81,
#  'Kampala': 81,
#  'Khalis': 81,
#  'Hit': 81,
#  'Shaykh Uthman': 80,
#  'Pir Koh': 80,
#  'Gardez': 80,
#  'Bangui': 80,
#  'Marawi': 78,
#  'Jolo': 77,
#  'Jalawla': 77,
#  'Guatemala city': 77,
#  'Guwahati': 77,
#  'Rio de Janeiro': 77,
#  'Ludhiana': 77,
#  'Usulutan': 76,
#  'Anantnag': 76,
#  'Vienna': 75,
#  'Farah': 75,
#  'Amman': 74,
#  'Saqlawiyah': 73,
#  'Balad Ruz': 73,
#  'Dera Murad Jamali': 73,
#  'Mardan': 73,
#  'Mandera': 73,
#  'Arsal': 73,
#  'Charsadda': 73,
#  'Lisbon': 73,
#  'Dujail': 73,
#  'Lahij': 72,
#  'Port Harcourt': 72,
#  'Marib': 71,
#  'Lurgan': 71,
#  'Montevideo': 71,
#  'Al-Baghdadi': 70,
#  'Ayacucho district': 69,
#  'Blida': 69,
#  'Hadithah': 69,
#  'Mallawi': 69,
#  'Khan Yunis': 68,
#  'Hayatabad': 68,
#  'Qarabagh district': 68,
#  'Bannang Sata': 68,
#  'Wana': 67,
#  'Eshkol regional council': 67,
#  'Tuz Khormato district': 67,
#  'Qayyarah': 67,
#  'Badaber': 67,
#  'Nicosia': 67,
#  'Luanda': 66,
#  'Maywand district': 66,
#  'Valencia': 66,
#  'Potiskum': 65,
#  'Strabane': 65,
#  'Jenin': 65,
#  'Kut': 65,
#  'Crossmaglen': 65,
#  'Nusaybin': 65,
#  'Mushahidah': 64,
#  'Barranquilla': 64,
#  'Mingora': 64,
#  'Sejar': 63,
#  'Alexandria': 63,
#  'Safi': 63,
#  'Nalchik': 63,
#  'South Waziristan district': 63,
#  'Santa Cruz': 63,
#  'Puli Khumri': 62,
#  'Portadown': 62,
#  'Quezon City': 62,
#  'Dungannon': 62,
#  'Pattani': 62,
#  'Giza': 62,
#  'Baiji district': 62,
#  'Andar district': 62,
#  'Hub': 62,
#  'Nowshera': 61,
#  'Saravena': 61,
#  'Sungai Kolok': 61,
#  'Panjgur': 61,
#  'Suchitoto': 61,
#  'Santo Domingo': 61,
#  'Hammam al-Alil': 61,
#  'Kiev': 60,
#  'Dera Bugti district': 60,
#  'Tyre': 60,
#  'Guayaquil': 60,
#  'Shirqat district': 59,
#  'Damaturu': 59,
#  'Sao Paulo': 59,
#  'Rutbah district': 59,
#  'Cologne': 59,
#  'Garissa': 58,
#  'Amiriyat al-Fallujah': 58,
#  'Apopa': 58,
#  'Marseilles': 58,
#  'Radhwaniyah': 57,
#  'Chicago': 57,
#  'San Sebastian': 57,
#  'Tikrit district': 57,
#  'Phnom Penh': 57,
#  'San Pedro Sula': 57,
#  'Jammu': 57,
#  'Nad Ali district': 57,
#  'Bala Buluk district': 57,
#  'Yangon': 56,
#  'Musa Qala district': 56,
#  'Cartagena': 56,
#  'Deir ez-Zor': 56,
#  'Cusco': 55,
#  'Pristina': 55,
#  'Kigali': 55,
#  'Mantaro district': 55,
#  'Buhriz': 55,
#  'Mastung': 55,
#  'Lisburn': 55,
#  'Latehar district': 55,
#  'Neiva': 54,
#  'Bethlehem': 54,
#  'Porto-Vecchio': 54,
#  'Callao': 54,
#  'Huanta': 54,
#  'Mir Ali': 53,
#  'Apartado': 53,
#  'Isabela': 53,
#  'Kabacan': 53,
#  'Shariff Aguak': 53,
#  'Swabi': 53,
#  'Munich': 52,
#  'Tbilisi': 52,
#  'Shyrokyne': 52,
#  'Batticaloa district': 52,
#  'Mattani': 52,
#  'Kidal': 52,
#  'Qoryoley': 52,
#  'Pretoria': 52,
#  'Asadabad': 52,
#  'Yarang': 51,
#  'Beni': 51,
#  'Ashdod': 51,
#  'Yathrib': 51,
#  'Luhansk': 51,
#  'Raman': 51,
#  'Bijapur district': 51,
#  'Maputo': 50,
#  'Sederot': 50,
#  'Soyapango': 50,
#  'Tibu': 50,
#  'Kohlu': 50,
#  'Leon': 50,
#  'North Waziristan district': 50,
#  'Sukma district': 49,
#  'Nasiriyah': 49,
#  'Florence': 49,
#  'Mazari Sharif': 49,
#  'Swat district': 49,
#  'Lamitan': 49,
#  'Beersheba': 48,
#  'Bologna': 48,
#  'Seiyun': 48,
#  'Saydabad district': 48,
#  'Odessa': 47,
#  'Mihtarlam': 47,
#  'Darjeeling': 47,
#  'Siniyah': 47,
#  'Zaragoza': 47,
#  'Baghlani Jadid district': 47,
#  'Khar': 47,
#  'unknown': 47,
#  'Kilis': 47,
#  'Chandigarh': 47,
#  'Constantine': 47,
#  'Spin Boldak': 47,
#  'Sirnak': 46,
#  'Santiago de Maria': 46,
#  'Diwaniyah': 46,
#  'Addis Ababa': 46,
#  'Shchastya': 46,
#  'Nyala': 46,
#  'Avdiivka': 46,
#  'Ordzhonikidzevskaya': 46,
#  'Pisky': 46,
#  'Bagram': 46,
#  'Slovyansk': 46,
#  'Taza Khurmatu': 46,
#  'Zaidan': 46,
#  'Narathiwat': 46,
#  'Cizre': 46,
#  'Khogyani district': 45,
#  'Multan': 45,
#  'Ajdabiya': 45,
#  'Huaraz': 45,
#  'Lagos': 45,
#  'Qaim': 45,
#  'Medellin district': 45,
#  'Pereira': 45,
#  'Tagab district': 45,
#  'Jos': 45,
#  'Delhi': 45,
#  'Dhuluiya': 45,
#  'Azim': 45,
#  'San Isidro': 44,
#  'Hawr Rajab': 44,
#  'Abu Ghraib district': 44,
#  'Musayib': 44,
#  'Hamamiyat': 44,
#  'Naples': 44,
#  'Bashir': 43,
#  'Rosario': 43,
#  'Sinjar': 43,
#  'Ain al-Hilweh': 43,
#  'Gao': 43,
#  'Kuwait': 43,
#  'Bayda': 43,
#  'Shahidi Hassas district': 43,
#  'Jurf al-Sakhar': 43,
#  'Cassoalala': 43,
#  'Darra Adam Khel': 43,
#  'Zacatecoluca': 43,
#  'Asyut': 43,
#  'Muqur district': 43,
#  'Marjah': 43,
#  'Adhaim': 43,
#  'Budapest': 42,
#  'Matta': 42,
#  'Pulwama': 42,
#  'Qaysar district': 42,
#  'Khok Pho': 42,
#  'San Carlos': 42,
#  'Gombe': 42,
#  'Shahjoy district': 42,
#  'Bardere': 42,
#  'Dali': 41,
#  'San Antonio': 41,
#  'Carmen': 41,
#  'Sibi': 41,
#  'Dantewada district': 41,
#  'Icolo e Bengo district': 41,
#  'Popayan': 41,
#  'Haifa': 41,
#  'West Midnapore district': 41,
#  'Arauca': 41,
#  'Qarah Tapah': 41,
#  'Dimapur': 41,
#  'Santa Rosa': 41,
#  'Buynaksk': 41,
#  'Huancavelica': 41,
#  'Rutbah': 41,
#  'Granada': 40,
#  'Kobani': 40,
#  'Gwadar': 40,
#  'Nasirabad': 40,
#  'Malkangiri district': 40,
#  'Manama': 40,
#  'Banda Aceh': 40,
#  'Khanaqin': 40,
#  'Temuco': 40,
#  'Shopian': 39,
#  'Ballymena': 39,
#  'Amsterdam': 39,
#  'Arequipa': 39,
#  'Seattle': 39,
#  'Ishaqi': 39,
#  'Uraba': 39,
#  'Chalatenango': 39,
#  'Parachinar': 39,
#  'Chattar': 39,
#  'Bacho': 39,
#  'Sulayman Beg': 39,
#  'Gitega': 39,
#  'Salisbury': 39,
#  'San Agustin': 39,
#  'Bati Kot district': 39,
#  'Huancavelica district': 39,
#  'Florencia': 38,
#  'Kaduna': 38,
#  'Balad district': 38,
#  'Timbuktu': 38,
#  'Shirin Tagab district': 38,
#  'Kech district': 38,
#  'Guadalajara': 38,
#  'Sariab': 38,
#  'Musayyib': 38,
#  'Kokrajhar district': 38,
#  'Trujillo': 38,
#  'Zaranj': 37,
#  'Stockholm': 37,
#  'Pikit': 37,
#  'Kalmunai': 37,
#  'Lawdar': 37,
#  'Semdinli district': 37,
#  'Irun': 37,
#  'Netzarim': 37,
#  'Stanytsia Luhanska': 37,
#  'Chora district': 37,
#  'Aguilares': 37,
#  'Rajshahi': 37,
#  'Corinto': 37,
#  'Tizi Ouzou': 37,
#  'Situbondo': 36,
#  'Khulna': 36,
#  'Radaa': 36,
#  'Sabha': 36,
#  'Bannu district': 36,
#  'Kharkiv': 36,
#  'Newtownabbey': 36,
#  'Goma': 36,
#  'Panjgur district': 36,
#  'Mariupol': 36,
#  'Copenhagen': 36,
#  'Dulab': 36,
#  'Mastung district': 36,
#  'Iligan': 36,
#  'Warduj district': 36,
#  'Antrim': 36,
#  'Dili': 36,
#  'Kalat': 35,
#  'Shindand': 35,
#  'Zab': 35,
#  'Bayonne': 35,
#  'Shah Wali Kot district': 35,
#  'Kinshasa': 35,
#  'Hasakah': 35,
#  'Misrata': 35,
#  'Najran': 35,
#  'Faiyum': 35,
#  'Sulaymaniyah': 35,
#  'Mombasa': 35,
#  'Jowhar': 35,
#  'Debaltseve': 35,
#  'Tral': 35,
#  'Rueso': 35,
#  'Nawa-i-Barakzayi district': 35,
#  'Warri': 35,
#  'Toulouse': 35,
#  'Beled Hawo': 35,
#  'Maydan Shahr': 35,
#  'General Santos': 35,
#  'Raqqah': 35,
#  'Santa Tecla': 35,
#  'Bijbehara': 34,
#  'Jalawlah': 34,
#  'Geneva': 34,
#  'Abu Sayda': 34,
#  'Maymana': 34,
#  'Sohbatpur': 34,
#  'Pusht Rod district': 34,
#  'Palamu district': 34,
#  'Jucuapa': 34,
#  'Kandy': 34,
#  'Zhari district': 34,
#  'Panjwai district': 34,
#  'Angeles': 34,
#  'Rawah': 34,
#  'Bulobarde': 34,
#  'Pagadian': 34,
#  'Dibis': 34,
#  'Dantewada': 34,
#  'Qush Tepa district': 33,
#  'Malgobek': 33,
#  'Baalbek': 33,
#  'Lakhdaria': 33,
#  'Horlivka': 33,
#  'Ahvaz': 33,
#  'Idlib': 33,
#  'Cukurca district': 33,
#  'Chennai': 33,
#  'Berkeley': 33,
#  'Asuncion': 33,
#  'San Fernando': 33,
#  'Baramulla': 33,
#  'Chimbote': 33,
#  'Khash Rod district': 33,
#  'Sarajevo': 33,
#  'Pasni': 33,
#  'Arbil': 33,
#  'Genoa': 33,
#  'Hat Yai': 33,
#  'Bijapur': 33,
#  'Muang Pattani district': 33,
#  'Tame': 33,
#  'Poso': 33,
#  'Medea': 33,
#  'Jalandhar': 33,
#  'Machh': 33,
#  'Najaf': 33,
#  'Ataq': 33,
#  'Sagone': 32,
#  'Qayarah': 32,
#  'Ghisonaccia': 32,
#  'Lyon': 32,
#  'Umlazi': 32,
#  'Sur district': 32,
#  'Katlehong': 32,
#  'Tumaco': 32,
#  'Sofia': 32,
#  'Jezzine': 32,
#  'Tingo Maria': 32,
#  'Piraeus': 32,
#  'La Union': 32,
#  'Tecoluca': 31,
#  'Nushki': 31,
#  'Batman': 31,
#  'Mand': 31,
#  'The Hague': 31,
#  'Seville': 31,
#  'San Rafael Cedros': 31,
#  'San Pablo': 31,
#  'Huancayo district': 31,
#  'Baraki Barak district': 31,
#  'Khwaja Sabz Posh district': 31,
#  'Corte': 31,
#  'Naw Zad district': 31,
#  'Nice': 31,
#  'Belgrade': 31,
#  'Almar district': 31,
#  'Hamah': 31,
#  'Kabal': 31,
#  'Logo district': 31,
#  'Midsayap': 31,
#  'Hit district': 31,
#  'Santa Clara': 31,
#  'Barakaldo': 31,
#  'Hudur': 31,
#  'Cookstown': 30,
#  'Wajir': 30,
#  'Mullaitivu': 30,
#  'Macao': 30,
#  'Omagh': 30,
#  'Ampara district': 30,
#  'Tank': 30,
#  'Huambo': 30,
#  'Lome': 30,
#  'Narita': 30,
#  'Taipei': 30,
#  'San Marcos': 30,
#  'Surat': 30,
#  'Alexandra': 30,
#  'Marawara district': 30,
#  'Sydney': 29,
#  'Khartoum': 29,
#  'Gizab district': 29,
#  'Khas Uruzgan district': 29,
#  'Ceel Buur': 29,
#  'Konduga': 29,
#  'Aguelhoc': 29,
#  'Manchester': 29,
#  'Cochabamba': 29,
#  'Rajbiraj': 29,
#  'San Martin': 29,
#  'Windhoek': 29,
#  'Muang Yala district': 29,
#  'Khorramshahr': 29,
#  'Achin district': 29,
#  'Bannang Sata district': 29,
#  'Nejapa': 29,
#  'Hermel': 29,
#  'Alingar district': 29,
#  'Lusaka': 28,
#  'Aka Khel': 28,
#  'Yuksekova district': 28,
#  'Dawr': 28,
#  'Ahmedabad': 28,
#  'Rusoh': 28,
#  'Hanover': 28,
#  'Minya': 28,
#  'Kingston': 28,
#  'Pashtun Kot district': 28,
#  'Chiclayo': 28,
#  'Kanker district': 28,
#  'Rueso district': 28,
#  'Darzab district': 28,
#  'Mutur': 28,
#  'Yarang district': 28,
#  'Samarra district': 28,
#  'Bolzano': 28,
#  'Kuchlak': 28,
#  'Mumbai': 28,
#  'Mannar': 28,
#  'Narayanpur district': 28,
#  'Deh Rahwod district': 28,
#  'Karabulak': 28,
#  'Tawilah': 28,
#  'Tak Bai district': 28,
#  'Birganj': 28,
#  'Guazapa': 27,
#  'Ra-ngae': 27,
#  'Palmyra': 27,
#  'Tolosa': 27,
#  'Nong Chik': 27,
#  'Dondo': 27,
#  'Tejutepeque': 27,
#  'Tunceli': 27,
#  'Eibar': 27,
#  'Zurich': 27,
#  'Tump': 27,
#  'San Diego': 27,
#  'Khuzdar district': 27,
#  'Quezaltepeque': 27,
#  'Cimitarra': 27,
#  'Ciudad Barrios': 27,
#  'Buenaventura': 27,
#  'Mohammad Agha district': 27,
#  'Wadh': 27,
#  'Faisalabad': 27,
#  'Dawlatabad district': 27,
#  'Santa Marta': 27,
#  'Bihsud district': 27,
#  'Moreh': 27,
#  'Sungai Padi district': 27,
#  'Anah': 27,
#  'Imam Sahib district': 27,
#  'Cinquera': 27,
#  'Sylhet': 27,
#  'Toribio': 27,
#  'Valaichchenai': 27,
#  'Barawe': 26,
#  'Lalgarh': 26,
#  'Spin Boldak district': 26,
#  'Gadchiroli district': 26,
#  'Venice': 26,
#  'Bonn': 26,
#  'Mahawil': 26,
#  'Trincomalee district': 26,
#  'Durango': 26,
#  'Mandali': 26,
#  'Tacurong': 26,
#  'Petah Tiqwa': 26,
#  'Malkangiri': 26,
#  'Saiburi': 26,
#  'Shaar HaNegev regional council': 26,
#  'Welioya': 26,
#  'Raman district': 26,
#  'Kutum': 26,
#  'La Plata': 26,
#  'Amarah': 26,
#  'Haswah': 26,
#  'Dih Yak district': 26,
#  'Tejutla': 26,
#  'Wihdah': 26,
#  'Dera Allah Yar': 26,
#  'Tulkarem': 25,
#  'Rangae district': 25,
#  'Pasajes': 25,
#  'Baku': 25,
#  'Lhokseumawe': 25,
#  'Sixth of October': 25,
#  'Dusseldorf': 25,
#  'Amritsar District': 25,
#  'Turbo': 25,
#  'Nong Chik district': 25,
#  'Sungai Padi': 25,
#  'Sai Buri district': 25,
#  'Qamishli': 25,
#  'Havana': 25,
#  'Ramadi district': 25,
#  'Guernica': 25,
#  'Mongla': 25,
#  'Mitrovica': 25,
#  'Dulce Nombre de Maria': 25,
#  'Kadugli': 25,
#  'Rancagua': 25,
#  'Pointe-a-Pitre': 25,
#  'Buni Yadi': 25,
#  'Ghormach district': 25,
#  'Netanya': 25,
#  'Quilali': 25,
#  'Nijrab district': 25,
#  'Bama': 25,
#  'Kabkabiya': 25,
#  'La Libertad': 25,
#  'Dashti Archi district': 25,
#  'Bombay': 25,
#  'Tirana': 25,
#  'Patikul': 25,
#  'Las Arenas': 25,
#  'Toledo': 24,
#  'Ilobasco': 24,
#  'Rashad': 24,
#  'San Ramon': 24,
#  'Errenteria': 24,
#  'Datta Khel': 24,
#  'Tetovo': 24,
#  'Khan Bani Saad': 24,
#  'Renteria': 24,
#  'Abuja': 24,
#  'Wajihiyah': 24,
#  'Buner district': 24,
#  'Georgetown': 24,
#  'Oran': 24,
#  'Kupwara': 24,
#  'Damboa': 24,
#  'Dayrut': 24,
#  'Nari district': 24,
#  'Puerto Rico': 24,
#  'Medan': 24,
#  'Sirwah district': 24,
#  'Jessore': 24,
#  'Jiquilisco': 24,
#  'San Pedro': 24,
#  'Miraflores': 24,
#  'Thoubal': 24,
#  'Nationwide': 24,
#  'Brazzaville': 24,
#  'Jaffna district': 24,
#  'Skopje': 24,
#  'Jaffarabad district': 24,
#  'Yaha': 24,
#  'Gilgit': 24,
#  'Puerto Asis': 24,
#  'Gulu': 24,
#  'Craigavon': 24,
#  'Prague': 24,
#  'Rangae': 23,
#  'Kanaan': 23,
#  'Lurigancho': 23,
#  'Limassol': 23,
#  'Salarzai': 23,
#  'Dir': 23,
#  'Metapan': 23,
#  'Bongaigaon': 23,
#  'Loti': 23,
#  'Bakwa district': 23,
#  'Datu Piang': 23,
#  'Alon Shvut': 23,
#  'Mahaday': 23,
#  'Bokaro district': 23,
#  'Nabatiyeh': 23,
#  'Kidapawan': 23,
#  'Pietermaritzburg': 23,
#  'Gwoza': 23,
#  'Thokoza': 23,
#  'Villafranca de Ordizia': 23,
#  'Kajaki district': 23,
#  'Denver': 23,
#  'Juba': 23,
#  'Rashidiyah': 23,
#  'Khunti district': 23,
#  'Coalisland': 23,
#  'Bouira': 23,
#  'La Maddalena': 23,
#  'Beida': 23,
#  'Qatn': 23,
#  'Escuintla': 23,
#  'Daraa': 23,
#  'Santander': 23,
#  'Afmadow': 23,
#  'Tulua': 22,
#  'Antalya': 22,
#  'Abu Qurqas': 22,
#  'Mashhad': 22,
#  'Marinka': 22,
#  'Maruf district': 22,
#  'Elizalde': 22,
#  'Karbi Anglong district': 22,
#  'Portland': 22,
#  'Imam Sahib': 22,
#  'Burhakaba': 22,
#  'Tharthar': 22,
#  'Qatif': 22,
#  'Gujranwala': 22,
#  'Chaparhar district': 22,
#  'Sumisip': 22,
#  'Hudaydah': 22,
#  'Hernani': 22,
#  'Larkana': 22,
#  'Baksan': 22,
#  'Zawiya': 22,
#  'Harare': 22,
#  'Basauri': 22,
#  'Kilinochchi': 22,
#  'Koraput district': 22,
#  'Chlef': 22,
#  'Awaran district': 22,
#  'Bremen': 22,
#  'Castlederg': 22,
#  'Sadda': 22,
#  'Gudermes': 22,
#  'Argun': 22,
#  'Batala': 22,
#  'Carolina': 22,
#  'Tank district': 22,
#  'Kiryat Arba': 22,
#  'Leego': 22,
#  'Rajouri': 22,
#  'El Wak': 22,
#  'Gaya': 22,
#  'Jericho': 22,
#  'Cizre district': 22,
#  'Newtownhamilton': 22,
#  'Riga': 22,
#  'Bentiu': 22,
#  'San Jose Guayabal': 22,
#  'Delaram': 22,
#  'Kolofata': 22,
#  'Halimzai': 22,
#  'Charbagh': 22,
#  'Anuradhapura': 22,
#  'Bonifacio': 22,
#  'Nepalganj': 22,
#  'Puno': 22,
#  'Jaar': 22,
#  'Cebu City': 21,
#  'Batticaloa District': 21,
#  'Chahar Dara district': 21,
#  'Tubruq': 21,
#  'Kulgam': 21,
#  'Bashiqah': 21,
#  'Noumea': 21,
#  'Sari Pul': 21,
#  'Santurce': 21,
#  'Bawi': 21,
#  'Chamkani': 21,
#  'Makhmur district': 21,
#  'Daquq district': 21,
#  'Eravur': 21,
#  'Sdot Negev regional council': 21,
#  'Shoqra': 21,
#  'Poblacion': 21,
#  'Muxungue': 21,
#  'Boufarik': 21,
#  'Madurai': 21,
#  'Ibague': 21,
#  'Galgala': 21,
#  'Palmira': 21,
#  'Sonsonate': 21,
#  'Khwaja Ghar district': 21,
#  'Wiwili': 21,
#  'North Cachar Hills district': 21,
#  'Kissufim': 21,
#  'Shillong': 21,
#  'Khairpur': 21,
#  'Giridih district': 21,
#  'Urus-Martan': 21,
#  'San Rafael': 21,
#  'Bishnupur': 21,
#  'Gaziantep': 21,
#  'Yerevan': 21,
#  'Al-Halabisah': 21,
#  'Midyat': 21,
#  'Huacho': 21,
#  'Nasirabad district': 21,
#  'Khemis Miliana': 21,
#  'Muqdadiyah district': 21,
#  'Talcahuano': 20,
#  'El Triunfo': 20,
#  'Larne': 20,
#  'Yumbo': 20,
#  'Lafoole': 20,
#  'Vladikavkaz': 20,
#  'Semdinli': 20,
#  'Jinotega': 20,
#  'Hakkari': 20,
#  'Ranchi': 20,
#  'East London': 20,
#  'Tyrnyauz': 20,
#  'A Coruna district': 20,
#  'Cho-airong district': 20,
#  'Ibb': 20,
#  'Lakki Marwat': 20,
#  'Jabaliya': 20,
#  'Erez': 20,
#  'Ahuachapan': 20,
#  'Bangalore': 20,
#  'Mach': 20,
#  'Yaha district': 20,
#  'Albu Shejel': 20,
#  'Khairabad': 20,
#  'Popasna': 20,
#  'Teorama': 20,
#  'Calvi': 20,
#  'Enniskillen': 20,
#  'Coimbatore': 20,
#  'Brahmanbaria': 20,
#  'Zahedan': 20,
#  'Kfar Darom': 20,
#  'Ukhrul': 20,
#  'Rio Negro': 20,
#  'Sharana': 20,
#  'Dadaab': 20,
#  'Qarabagh': 20,
#  'Armenia': 20,
#  'Morghab district': 20,
#  'Las Vueltas': 20,
#  ...}

# %%
df1['City'] = df1['City'].fillna('Unknown')

# %%
lat=df1['Latitude'].value_counts().to_dict()
lat
# Out:
# {33.303566: 7521,
#  24.891115: 2686,
#  -11.967368: 2401,
#  36.354145: 2247,
#  54.607712: 2189,
#  -33.366238: 1562,
#  13.69288: 1559,
#  2.059819: 1536,
#  41.106178: 1052,
#  37.99749: 1017,
#  4.667128: 990,
#  33.888523: 914,
#  35.45211: 907,
#  6.242026: 857,
#  14.622869: 849,
#  32.069286: 831,
#  30.200819: 793,
#  -3.495702: 18,
#  43.00732: 18,
#  33.193142: 18,
#  15.587991: 18,
#  31.374899: 18,
#  30.66667: 18,
#  33.266693: 18,
#  42.672479: 18,
#  54.253718: 18,
#  36.37489: 18,
#  32.606209: 18,
#  13.90668: 18,
#  6.541102: 18,
#  13.1: 18,
#  33.447155: 18,
#  43.230556: 18,
#  27.66897: 18,
#  38.888447: 18,
#  36.001646: 18,
#  11.509748: 18,
#  32.154514: 18,
#  -13.755419: 18,
#  3.312293: 18,
#  3.583748: 18,
#  48.777106: 18,
#  13.09171: 18,
#  4.085809: 18,
#  29.554548: 18,
#  36.803501: 18,
#  6.41871: 18,
#  15.408333: 18,
#  35.167134: 18,
#  34.707332: 18,
#  54.684823: 18,
#  22.65735: 18,
#  ...}

# %%
# creating a dictionary from city and latitude columns
city_lat = dict(zip(df1['City'], df1['Latitude']))

#print('The dictionary city_lat is:',city_lat)

# filling the  missing latitude values with corresponding city's latitude
df1['Latitude'] = df1['Latitude'].fillna(df1['City'].map(city_lat))
df1['Latitude'].isnull().sum()
# Out:
# 1947

# %%
# filling the other latitudes with 0
df1['Latitude'] = df1['Latitude'].fillna(0)

# %%
#same for longitudes!
# creating a dictionary from city and Logitude columns
city_lon = dict(zip(df1['City'], df1['Longitude']))

#print('The dictionary city_lat is:',city_lat)

# filling the  missing latitude values with corresponding city's latitude
df1['Longitude'] = df1['Longitude'].fillna(df1['City'].map(city_lon))
df1['Longitude'].isnull().sum()
# Out:
# 1948

# %%
# filling the other Longitude with 0
df1['Longitude'] = df1['Longitude'].fillna(0)

# %%
# fill the number of kills and wounds based on the weapon used by the terrorist!!

# creating a dictionary from Fatalities and Weapon_type columns
weap_fatal = dict(zip(df1['WeaponType'], df1['Fatalities']))

df1['Fatalities'] = df1['Fatalities'].fillna(df1['WeaponType'].map(weap_fatal))
df1['Fatalities'].isnull().sum()
# Out:
# 0

# %%
# creating a dictionary from Injured and Weapon_type  columns

weap_inj = dict(zip(df1['WeaponType'], df1['Injuries']))

df1['Injuries'] = df1['Injuries'].fillna(df1['WeaponType'].map(weap_inj))
df1['Injuries'].isnull().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Country     181691 non-null  object
#  1   Region      181691 non-null  object
#  2   City        181691 non-null  object
#  3   Latitude    181691 non-null  float64
#  4   Longitude   181691 non-null  float64
#  5   AttackType  181691 non-null  object
#  6   TargetType  181691 non-null  object
#  7   WeaponType  181691 non-null  object
#  8   Fatalities  181691 non-null  float64
#  9   Injuries    181691 non-null  float64
#  10  Date        180800 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(6)
# memory usage: 15.2+ MB

# %% [markdown]
# # EDA!!

# %%
# Bar chart of terrorist attacks by country


# country counts and filter by count > 1000
'''country = df1['Country'].value_counts()
country_top = country[country > 1000]

country_top.plot(kind='bar')
'''
# top 35 countries in terrorist activities
df1['Country'].value_counts()[:35].plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
# Analysis on Countries:
#     there are top four countries that have high terrorist attacts!! after then, there is quite lesser
#     attacks
#
# Iraq
# Pakistan
# Afghanisthan
# India

# %%
# Bar chart of terrorist attacks by city

df1['City'].value_counts()[:40].plot(kind='bar')
# Out:
# <Axes: >

# %%
# Bar chart of terrorist attacks by region

df1['Region'].value_counts().plot(kind='bar',figsize=(12,6))
# Out:
# <Axes: >

# %% [raw]
# Analysis on Regions:
#     Africa has more impact in terrorism as the Countries Analysis suggests, mostly in the top 35
#     theAfrican countries like Nigeria, Somalia,South Africa
#
#     It is followed by the Asian countries like Iran, Pakistan, India!

# %%
# Bar chart of terrorist attacks by attack type

df1['AttackType'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
# Analysis on Attack type:
#     mostly bombing or any flight attacks are common
#     then the armed assaults
# This is quite usual
# and the least possibilities are hijacking and hostage capturing!

# %%
# Bar chart of terrorist targets by Target Type  

df1['TargetType'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
# Analysis on terrorist attack target :
#     Terrorist attack on the higher officials , Military, Police or Targeting on Public places
#     in order to get down the country's economy

# %%
# Bar chart of terrorist weapons by Weapon Type  

df1['WeaponType'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
# Analysis on AttackType:
#     The terrorist attacks are mostly based on Bombing, causing damages from firearms
#
#     the least possible way is by Tricking or by Bio-war!!

# %%
#Fatalities  
# Bar chart of terrorist weapons by Weapon Type  

df1['Fatalities'].value_counts().plot(kind='kde')
print('the most death rate:',df1['Fatalities'].max())
print('the least death rate:',df1['Fatalities'].min())
print('the death rate on average',int(df1['Fatalities'].mean()))
# Out:
# the most death rate: 1570.0
# the least death rate: 0.0
# the death rate on average 2

# %%
#df1['Fatalities'].std()
# the average dead rate is 2, but usually the dead rates vary, they dont follow a fashion
dead=df1[df1['Fatalities']<20]
dead['Fatalities'].plot(kind='box')
# Out:
# <Axes: >

# %%
# log transformation on Fatalities
df1['Fatalities']=df1['Fatalities'].apply(lambda x:np.log(x+1))

# %%
df1['Fatalities'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Country     181691 non-null  object
#  1   Region      181691 non-null  object
#  2   City        181691 non-null  object
#  3   Latitude    181691 non-null  float64
#  4   Longitude   181691 non-null  float64
#  5   AttackType  181691 non-null  object
#  6   TargetType  181691 non-null  object
#  7   WeaponType  181691 non-null  object
#  8   Fatalities  181691 non-null  float64
#  9   Injuries    181691 non-null  float64
#  10  Date        180800 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(6)
# memory usage: 15.2+ MB

# %%
import seaborn as sns
 
sns.barplot(y='WeaponType',x='Fatalities',data=df1)
# Out:
# <Axes: xlabel='Fatalities', ylabel='WeaponType'>

# %% [raw]
# Acc. to the data , most casualty occurred during the Bombs and Firearms

# %%
sns.barplot(y='WeaponType',x='Injuries',data=df1)
# Out:
# <Axes: xlabel='Injuries', ylabel='WeaponType'>

# %% [raw]
# Most of the injuries are because of bombing , chemical and some bio-attack

# %% [markdown]
# Multi-variate Analysis

# %%
sns.pairplot(df1)

# %%
sns.heatmap(df1.corr())

# %%
num_df=df1.select_dtypes(include=['float64'])
num_df.columns

# %%
num_df.plot(kind='kde',subplots=True,layout=(1,1),figsize=(20,10))
